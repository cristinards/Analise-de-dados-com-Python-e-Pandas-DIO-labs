# %%
print('Ola mundo')
# Out:
# Ola mundo

# %%
"estou aprendendo python"
# Out:
# 'estou aprendendo python'

# %%
1+1
# Out:
# 2

# %%
10-2
# Out:
# 8

# %%
#Comentario em python

# %%
#multiplicaçao
2*2
# Out:
# 4

# %%
#divisao
10/2
# Out:
# 5.0

# %%
a = 4
b = 6

# %%
a + b
# Out:
# 10

# %%
frase = 'Python para Análise de Dados'

# %%
frase[0]
# Out:
# 'P'

# %%
# a notação de fatiamento é inclusiva à esquerda, mas não à direita
frase[0:10]
# Out:
# 'Python par'

# %%
frase[10:]
# Out:
# 'a Análise de Dados'

# %%
frase[:17]
# Out:
# 'Python para Análi'

# %%
frase.count('Dados')
# Out:
# 1

# %%
frase.lower()
# Out:
# 'python para análise de dados'

# %%
frase.upper()
# Out:
# 'PYTHON PARA ANÁLISE DE DADOS'

# %%
frase.replace('Python', 'R')
# Out:
# 'R para Análise de Dados'

# %%
frase = frase.upper()

# %%
frase
# Out:
# 'PYTHON PARA ANÁLISE DE DADOS'
