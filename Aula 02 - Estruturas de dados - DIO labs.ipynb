# %% [markdown]
# ###Listas

# %%
#Criando Lista
animais = [1,2,3]
animais
# Out:
# [1, 2, 3]

# %%
animais = ["Cachorro", "gato", 12345, 6.5]
animais
# Out:
# ['Cachorro', 'gato', 12345, 6.5]

# %%
#imprimindo o 4 elemento da lista
animais[0]
# Out:
# 'Cachorro'

# %%
#substituindo o primeiro elemento da lista
animais[0] = "papagaio"
animais
# Out:
# ['papagaio', 'gato', 12345, 6.5]

# %%
#remove gato da list
animais.remove("gato")
animais
# Out:
# ['papagaio', 12345, 6.5]

# %%
len(animais)
# Out:
# 3

# %%
"gato" in animais
# Out:
# False

# %%
lista = [500,30,300,80,10]

# %%
max(lista)
# Out:
# 500

# %%
min(lista)
# Out:
# 10

# %%
animais.append("leao")

# %%
animais
# Out:
# ['papagaio', 12345, 6.5, 'leao']

# %%
animais.extend(["cobra",6])

# %%
animais
# Out:
# ['papagaio', 12345, 6.5, 'leao', 'cobra', 6]

# %%
animais.count("cachorro")
animais
# Out:
# ['papagaio', 12345, 6.5, 'leao', 'cobra', 6]

# %%
lista.sort()
animais
# Out:
# ['papagaio', 12345, 6.5, 'leao', 'cobra', 6]

# %%
lista
# Out:
# [10, 30, 80, 300, 500]

# %% [markdown]
# ### Tuplas

# %%
tp = ("Banana", "maça", 10,50)

# %%
tp[0]
# Out:
# 'Banana'

# %%
#tp[0] = "laranja"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-a103dc83a21e> in <module>()
# ----> 1 tp[0] = "laranja"
#
# TypeError: 'tuple' object does not support item assignment

# %%
tp.count("maça")
# Out:
# 1

# %%
tp[0:2]
# Out:
# ('Banana', 'maça')

# %% [markdown]
# ### Dicionario

# %%
dc = {"maça":20, "banana":10, "laranja":15, "uva":5}

# %%
dc
# Out:
# {'banana': 10, 'laranja': 15, 'maça': 20, 'uva': 5}

# %%
dc["maça"]
# Out:
# 20

# %%
dc["maça"] = 25

# %%
dc
# Out:
# {'banana': 10, 'laranja': 15, 'maça': 25, 'uva': 5}

# %%
dc.keys()
# Out:
# dict_keys(['maça', 'banana', 'laranja', 'uva'])

# %%
dc.values()
# Out:
# dict_values([25, 10, 15, 5])

# %%
dc.setdefault("limao",22)
# Out:
# 22

# %%
dc
# Out:
# {'banana': 10, 'laranja': 15, 'limao': 22, 'maça': 25, 'uva': 5}
